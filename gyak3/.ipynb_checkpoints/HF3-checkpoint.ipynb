# %% [markdown]
# # 3. Házi feladat
#
#
# Hányadikig kell összeadni az elemeket az
#
# $$ a_{n\:}=3n\:-1,\quad n\geq 0$$
#
# sorozatban, hogy 19-cel osztható páratlan számot kapjunk? Az egész mondatos választ írassuk ki a képernyőre. (Pl.: "A sorozat elemeit a(z) xxx. elemig kell összeadni.")

# %% [markdown]
# A FB-string a következő módon alakul ki. Kezdetben üres. Végigmegyünk az összes pozitív egész számon, kezdve 1-gyel, növekvő sorrendben, és a következőt tesszük minden egyes egész számmal:
#
# - Ha az aktuális egész osztható 3-mal, F-t fűzünk az FB-sztring végére;
# - Ha az aktuális egész osztható 5-tel, B-t fűzünk az FB-sztring végére.
#
# Megjegyzés: Ha egy egész osztható mind 3-mal, mind 5-tel, akkor F-et, majd B-t fűzünk hozzá, nem fordítva.
#
# Az FB-string első 10 karaktere FBFFBFFBFB: az első F az 1-gyel oszthatatlan 3-as számból származik, a következő karakter (B) az 5-össel osztható számból származik, az következő F a 6-tal osztható számból származik, és így tovább. Egyszerű látni, hogy ez a karakterlánc végtelen hosszú. Legyen 𝑓𝑖 az FB-string 𝑖-edik karaktere, tehát 𝑓1 F, 𝑓2 B, 𝑓3 F, 𝑓4 F, és így tovább.
#
# Adott egy sztring 𝑠, amely F és/vagy B karakterekből áll. Meg kell határoznod, hogy ez egy substring-e (összefüggő részsorozat) az FB-string-ből. Más szóval meg kell határoznod, hogy lehetséges-e választani két egész számot 𝑙 és 𝑟 (1≤𝑙≤𝑟), hogy a 𝑓𝑙𝑓𝑙+1𝑓𝑙+2…𝑓𝑟 karakterlánc pontosan 𝑠 legyen.
#
# Például:
#
#     FFB egy substring az FB-string-ből: ha 𝑙=3 és 𝑟=5, akkor a 𝑓3𝑓4𝑓5 karakterlánc pontosan FFB;
#     BFFBFFBF egy substring az FB-string-ből: ha 𝑙=2 és 𝑟=9, akkor a 𝑓2𝑓3𝑓4…𝑓9 karakterlánc pontosan BFFBFFBF;
#     BBB nem substring az FB-string-ből.
